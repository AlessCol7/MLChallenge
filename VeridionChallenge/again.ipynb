# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm  # For progress tracking

# Ensure necessary NLTK resources are available
import nltk
nltk.data.path.append("/usr/local/share/nltk_data")  # Adjust this path if necessary
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Step 1: Load company dataset
company_df = pd.read_csv("ml_insurance_challenge.csv")
# Step 2: Load insurance taxonomy labels with corresponding insurance types
insurance_labels_df = pd.read_excel("insurance_taxonomy.xlsx", header=None, names=["Label"])
insurance_labels = insurance_labels_df["Label"].tolist()
print(insurance_labels)
#remove the first element
insurance_labels = insurance_labels[1:]
print(insurance_labels)
# Step 3: Assign numerical labels to insurance categories
label_to_id = {label: idx + 1 for idx, label in enumerate(insurance_labels)}
id_to_label = {idx + 1: label for idx, label in enumerate(insurance_labels)}

#Print the label to id mapping
print(label_to_id)
print(id_to_label)

#show the label of id 5
print(id_to_label[5])
# Step 4: Load GloVe word embeddings
def load_glove_embeddings(filepath, dim=300):
    embeddings = {}
    with open(filepath, "r", encoding="utf-8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype="float32")
            embeddings[word] = vector
    return embeddings

glove_embeddings = load_glove_embeddings("glove.6B.300d.txt")
def text_to_glove_vector(text, glove_embeddings):
    words = text.split()  # Simple tokenization
    vectors = [glove_embeddings.get(word, np.zeros(300)) for word in words]  # Default to zero vector if word is unknown
    return np.mean(vectors, axis=0) if vectors else np.zeros(300)
# Step 5: Preprocess text descriptions
def preprocess_text(text):
    if not isinstance(text, str) or pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    tokens = re.findall(r'\b\w+\b', text)  # Alternative tokenization method
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return " ".join(tokens)
def preprocess_all_columns(row):
    # Combine text from all relevant columns into one string
    combined_text = " ".join([str(row[col]) for col in ['business_tags', "niche", "category", "description"]])
    
    # Preprocess the combined text
    return preprocess_text(combined_text)
company_df['processed_combined_text'] = company_df.apply(preprocess_all_columns, axis=1)
company_df['glove_vector'] = company_df['processed_combined_text'].apply(lambda x: text_to_glove_vector(x, glove_embeddings))
# Step 8: Convert insurance labels to vectors
insurance_label_vectors = np.vstack([text_to_glove_vector(label, glove_embeddings) for label in insurance_labels])
# Step 9: Compute cosine similarity between company descriptions and insurance labels
company_vectors = np.vstack(company_df['glove_vector'].values)
similarity_matrix = cosine_similarity(company_vectors, insurance_label_vectors)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def assign_labels(similarity_matrix, labels, label_to_id):
    top_indices = np.argmax(similarity_matrix, axis=1)
    
    assigned_labels = []
    
    for index in top_indices:
        # Assign labels as numeric values
        numeric_label = label_to_id.get(labels[index], -1)
        assigned_labels.append(numeric_label)
    
    return assigned_labels

# Step 2: Load insurance taxonomy labels with corresponding insurance types
insurance_labels_df = pd.read_excel("insurance_taxonomy.xlsx", header=None, names=["Label"])
insurance_labels = insurance_labels_df["Label"].tolist()
# Remove the first element
insurance_labels = insurance_labels[1:]

# Step 3: Assign numerical labels to insurance categories
label_to_id = {label: idx + 1 for idx, label in enumerate(insurance_labels)}
id_to_label = {idx + 1: label for idx, label in enumerate(insurance_labels)}

# Print the label to id mapping
print(label_to_id)
print(id_to_label)

# Show the label of id 5
print(id_to_label[5])

# Load your actual company data
company_df = pd.read_csv("ml_insurance_challenge.csv")  # Replace with your actual data file

# Fill missing values in the 'description' column with an empty string
company_df['description'] = company_df['description'].fillna('')

# Combine company descriptions with insurance labels for TF-IDF vectorization
combined_texts = company_df['description'].tolist() + insurance_labels
# Generate the similarity matrix using TF-IDF and cosine similarity
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(combined_texts)
company_tfidf = tfidf_matrix[:len(company_df)]
label_tfidf = tfidf_matrix[len(company_df):]

similarity_matrix = cosine_similarity(company_tfidf, label_tfidf)

# Re-run the assignment
company_df['insurance_label_id'] = assign_labels(
    similarity_matrix, insurance_labels, label_to_id
)

# Count the occurrences of each label ID
label_counts = company_df['insurance_label_id'].value_counts()

# Print the label name with the label id and the number of companies assigned to that label
for label in label_counts.index:
    print(id_to_label[int(label)])
    print(f"id: {label}, label Counts: {label_counts[label]}")

# Create a bar chart
plt.figure(figsize=(70, 30))
plt.bar(label_counts.index.astype(str), label_counts.values, color='skyblue')
plt.xlabel("Insurance Label ID")
plt.ylabel("Number of Companies Assigned")
plt.title("Distribution of Companies by Insurance Label ID")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def assign_labels(similarity_matrix, labels, label_to_id):
    top_indices = np.argmax(similarity_matrix, axis=1)
    
    assigned_labels = []
    
    for index in top_indices:
        # Assign labels as numeric values
        numeric_label = label_to_id.get(labels[index], -1)
        assigned_labels.append(numeric_label)
    
    return assigned_labels

# Load insurance taxonomy labels with corresponding insurance types
insurance_labels_df = pd.read_excel("insurance_taxonomy.xlsx", header=None, names=["Label"])
insurance_labels = insurance_labels_df["Label"].tolist()
insurance_labels = insurance_labels[1:]  # Remove the first element

# Assign numerical labels to insurance categories
label_to_id = {label: idx + 1 for idx, label in enumerate(insurance_labels)}
id_to_label = {idx + 1: label for idx, label in enumerate(insurance_labels)}

# Load company data
company_df = pd.read_csv("ml_insurance_challenge.csv")  # Replace with actual data file

# Fill missing values in the 'description' column with an empty string
company_df['description'] = company_df['description'].fillna('')

# Combine company descriptions with insurance labels for TF-IDF vectorization
combined_texts = company_df['description'].tolist() + insurance_labels
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(combined_texts)
company_tfidf = tfidf_matrix[:len(company_df)]
label_tfidf = tfidf_matrix[len(company_df):]

# Compute similarity matrix
similarity_matrix = cosine_similarity(company_tfidf, label_tfidf)

# Assign labels
company_df['insurance_label_id'] = assign_labels(similarity_matrix, insurance_labels, label_to_id)

# Map label IDs back to label names
company_df['insurance_label_name'] = company_df['insurance_label_id'].map(id_to_label)

# Save results to a CSV file
output_file = "company_insurance_classification.csv"
company_df.to_csv(output_file, index=False)

print(f"Results saved to {output_file}")

# Count occurrences of each label ID
label_counts = company_df['insurance_label_id'].value_counts()

# Print label statistics
for label in label_counts.index:
    print(f"{id_to_label[int(label)]} (ID: {label}) - {label_counts[label]} companies")

# Create a bar chart
plt.figure(figsize=(70, 30))
plt.bar(label_counts.index.astype(str), label_counts.values, color='skyblue')
plt.xlabel("Insurance Label ID")
plt.ylabel("Number of Companies Assigned")
plt.title("Distribution of Companies by Insurance Label ID")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alessiacolumban/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/alessiacolumban/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/alessiacolumban/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/alessiacolumban/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ['label', 'Agricultural Equipment Services', 'Soil Nutrient Application Services', 'Pesticide Application Services', 'Ornamental Plant Nurseries', 'Landscaping Services', 'Gardening Services', 'Tree Services - Pruning / Removal', 'Veterinary Services', 'Veterinary Clinics', 'Pet Boarding Services', 'Animal Day Care Services', 'Pet Grooming Services', 'Animal Training Services', 'Veterinary Health Centers', 'Animal Trainers', 'Livestock Dealer Services', 'Timber Harvesting Operations', 'Fishing and Hunting Services', 'Well Maintenance Services', 'Field Welding Services', 'Sand and Gravel Mining', 'Residential Driveway Construction', 'Commercial Driveway Construction', 'Fencing Construction Services', 'Sidewalk Construction Services', 'Commercial Irrigation Systems', 'Residential Drainage Systems', 'Residential Snow Removal', 'Commercial Snow Removal', 'General Snow Removal Services', 'Land Leveling Services', 'Residential Drain Cleaning', 'Commercial Drain Cleaning', 'Street Cleaning Operations', 'Conveyor System Installation', 'Low-Rise Signage Installation', 'High-Rise Signage Installation', 'Tank Installation Services', 'Residential Communication Equipment Installation', 'Commercial Communication Equipment Installation', 'Low-Rise Glass Installation', 'High-Rise Glass Installation', 'Industrial Machinery Installation', 'Agricultural Machinery Installation', 'Grain Handling Machinery Installation', 'Dock and Pier Construction', 'Road and Highway Construction', 'Road Maintenance Services', 'Pipeline Construction Services', 'New Ground Pipeline Installation', 'Excavation Services', 'Residential Plumbing Services', 'Commercial Plumbing Services', 'Industrial Plumbing Services', 'Boiler Installation Services', 'Boiler Repair Services', 'Steam Services', 'Gas Installation Services', 'Medical Gas Installation Services', 'Fire Protection System Services', 'HVAC Installation and Service', 'HVAC Inspections', 'Air Duct Cleaning Services', 'Water Treatment Services', 'Residential Electrical Services', 'Commercial Electrical Services', 'Alarm Installation Services', 'Electric Line Construction', 'Cable Installation Services', 'Elevator Installation Services', 'Low-Rise Foundation Construction', 'High-Rise Foundation Construction', 'Precast Concrete Installation', 'Tilt-Up Concrete Services', 'Masonry Construction Services', 'Drywall Services', 'Tile Installation Services', 'Carpentry Services', 'Millwork Services', 'General Handyman Services', 'Insulation Services', 'Painting Services', 'Spray Painting Services', 'Flooring Installation Services', 'Interior Design Services', 'Home Staging Services', 'Sheet Metal Services', 'Welding Services', 'Structural Steel Erection', 'Non-Structural Steel Fabrication', 'Windows and Doors Installation', 'Well Drilling Services', 'Directional Drilling Services', 'Infrastructure Excavation', 'New Ground Excavation', 'Residential Roofing Services', 'Roofing Services with Heat Application', 'Waterproofing Services', 'Septic System Services', 'Building Cleaning Services', 'Fire Safety Equipment Services', 'Testing and Inspection Services', 'Single Family Residential Construction', 'Single Family Renovation Services', 'Multi-Family Construction Services', 'Apartment Renovation Services', 'Restoration Services', 'Mobile Home Construction Services', 'Commercial Construction Services', 'Commercial Renovation Services', 'Swimming Pool Installation Services', 'Swimming Pool Maintenance Services', 'Vacant Building Management', 'Vacant Land Services', 'Meat Processing Services', 'Seafood Processing Services', 'Dairy Production Services', 'Frozen Food Processing', 'Ice Production Services', 'Canning Services', 'Animal Feed Manufacturing', 'Pet Food Manufacturing', 'Grain Processing Services', 'Coffee Processing Services', 'Seed Processing Services', 'Bakery Production Services', 'Confectionery Manufacturing', 'Distilling Services', 'Brewery Operations', 'Non-Alcoholic Beverage Manufacturing', 'Oil and Fat Manufactu ...
# ['Agricultural Equipment Services', 'Soil Nutrient Application Services', 'Pesticide Application Services', 'Ornamental Plant Nurseries', 'Landscaping Services', 'Gardening Services', 'Tree Services - Pruning / Removal', 'Veterinary Services', 'Veterinary Clinics', 'Pet Boarding Services', 'Animal Day Care Services', 'Pet Grooming Services', 'Animal Training Services', 'Veterinary Health Centers', 'Animal Trainers', 'Livestock Dealer Services', 'Timber Harvesting Operations', 'Fishing and Hunting Services', 'Well Maintenance Services', 'Field Welding Services', 'Sand and Gravel Mining', 'Residential Driveway Construction', 'Commercial Driveway Construction', 'Fencing Construction Services', 'Sidewalk Construction Services', 'Commercial Irrigation Systems', 'Residential Drainage Systems', 'Residential Snow Removal', 'Commercial Snow Removal', 'General Snow Removal Services', 'Land Leveling Services', 'Residential Drain Cleaning', 'Commercial Drain Cleaning', 'Street Cleaning Operations', 'Conveyor System Installation', 'Low-Rise Signage Installation', 'High-Rise Signage Installation', 'Tank Installation Services', 'Residential Communication Equipment Installation', 'Commercial Communication Equipment Installation', 'Low-Rise Glass Installation', 'High-Rise Glass Installation', 'Industrial Machinery Installation', 'Agricultural Machinery Installation', 'Grain Handling Machinery Installation', 'Dock and Pier Construction', 'Road and Highway Construction', 'Road Maintenance Services', 'Pipeline Construction Services', 'New Ground Pipeline Installation', 'Excavation Services', 'Residential Plumbing Services', 'Commercial Plumbing Services', 'Industrial Plumbing Services', 'Boiler Installation Services', 'Boiler Repair Services', 'Steam Services', 'Gas Installation Services', 'Medical Gas Installation Services', 'Fire Protection System Services', 'HVAC Installation and Service', 'HVAC Inspections', 'Air Duct Cleaning Services', 'Water Treatment Services', 'Residential Electrical Services', 'Commercial Electrical Services', 'Alarm Installation Services', 'Electric Line Construction', 'Cable Installation Services', 'Elevator Installation Services', 'Low-Rise Foundation Construction', 'High-Rise Foundation Construction', 'Precast Concrete Installation', 'Tilt-Up Concrete Services', 'Masonry Construction Services', 'Drywall Services', 'Tile Installation Services', 'Carpentry Services', 'Millwork Services', 'General Handyman Services', 'Insulation Services', 'Painting Services', 'Spray Painting Services', 'Flooring Installation Services', 'Interior Design Services', 'Home Staging Services', 'Sheet Metal Services', 'Welding Services', 'Structural Steel Erection', 'Non-Structural Steel Fabrication', 'Windows and Doors Installation', 'Well Drilling Services', 'Directional Drilling Services', 'Infrastructure Excavation', 'New Ground Excavation', 'Residential Roofing Services', 'Roofing Services with Heat Application', 'Waterproofing Services', 'Septic System Services', 'Building Cleaning Services', 'Fire Safety Equipment Services', 'Testing and Inspection Services', 'Single Family Residential Construction', 'Single Family Renovation Services', 'Multi-Family Construction Services', 'Apartment Renovation Services', 'Restoration Services', 'Mobile Home Construction Services', 'Commercial Construction Services', 'Commercial Renovation Services', 'Swimming Pool Installation Services', 'Swimming Pool Maintenance Services', 'Vacant Building Management', 'Vacant Land Services', 'Meat Processing Services', 'Seafood Processing Services', 'Dairy Production Services', 'Frozen Food Processing', 'Ice Production Services', 'Canning Services', 'Animal Feed Manufacturing', 'Pet Food Manufacturing', 'Grain Processing Services', 'Coffee Processing Services', 'Seed Processing Services', 'Bakery Production Services', 'Confectionery Manufacturing', 'Distilling Services', 'Brewery Operations', 'Non-Alcoholic Beverage Manufacturing', 'Oil and Fat Manufacturing', 'R ...
# {'Agricultural Equipment Services': 1, 'Soil Nutrient Application Services': 2, 'Pesticide Application Services': 3, 'Ornamental Plant Nurseries': 4, 'Landscaping Services': 5, 'Gardening Services': 6, 'Tree Services - Pruning / Removal': 7, 'Veterinary Services': 8, 'Veterinary Clinics': 9, 'Pet Boarding Services': 10, 'Animal Day Care Services': 11, 'Pet Grooming Services': 12, 'Animal Training Services': 13, 'Veterinary Health Centers': 14, 'Animal Trainers': 15, 'Livestock Dealer Services': 16, 'Timber Harvesting Operations': 17, 'Fishing and Hunting Services': 18, 'Well Maintenance Services': 19, 'Field Welding Services': 20, 'Sand and Gravel Mining': 21, 'Residential Driveway Construction': 22, 'Commercial Driveway Construction': 23, 'Fencing Construction Services': 24, 'Sidewalk Construction Services': 25, 'Commercial Irrigation Systems': 26, 'Residential Drainage Systems': 27, 'Residential Snow Removal': 28, 'Commercial Snow Removal': 29, 'General Snow Removal Services': 30, 'Land Leveling Services': 31, 'Residential Drain Cleaning': 32, 'Commercial Drain Cleaning': 33, 'Street Cleaning Operations': 34, 'Conveyor System Installation': 35, 'Low-Rise Signage Installation': 36, 'High-Rise Signage Installation': 37, 'Tank Installation Services': 38, 'Residential Communication Equipment Installation': 39, 'Commercial Communication Equipment Installation': 40, 'Low-Rise Glass Installation': 41, 'High-Rise Glass Installation': 42, 'Industrial Machinery Installation': 43, 'Agricultural Machinery Installation': 44, 'Grain Handling Machinery Installation': 45, 'Dock and Pier Construction': 46, 'Road and Highway Construction': 47, 'Road Maintenance Services': 48, 'Pipeline Construction Services': 49, 'New Ground Pipeline Installation': 50, 'Excavation Services': 51, 'Residential Plumbing Services': 52, 'Commercial Plumbing Services': 53, 'Industrial Plumbing Services': 54, 'Boiler Installation Services': 55, 'Boiler Repair Services': 56, 'Steam Services': 57, 'Gas Installation Services': 58, 'Medical Gas Installation Services': 59, 'Fire Protection System Services': 60, 'HVAC Installation and Service': 61, 'HVAC Inspections': 62, 'Air Duct Cleaning Services': 63, 'Water Treatment Services': 64, 'Residential Electrical Services': 65, 'Commercial Electrical Services': 66, 'Alarm Installation Services': 67, 'Electric Line Construction': 68, 'Cable Installation Services': 69, 'Elevator Installation Services': 70, 'Low-Rise Foundation Construction': 71, 'High-Rise Foundation Construction': 72, 'Precast Concrete Installation': 73, 'Tilt-Up Concrete Services': 74, 'Masonry Construction Services': 75, 'Drywall Services': 76, 'Tile Installation Services': 77, 'Carpentry Services': 78, 'Millwork Services': 79, 'General Handyman Services': 80, 'Insulation Services': 81, 'Painting Services': 82, 'Spray Painting Services': 83, 'Flooring Installation Services': 84, 'Interior Design Services': 85, 'Home Staging Services': 86, 'Sheet Metal Services': 87, 'Welding Services': 88, 'Structural Steel Erection': 89, 'Non-Structural Steel Fabrication': 90, 'Windows and Doors Installation': 91, 'Well Drilling Services': 92, 'Directional Drilling Services': 93, 'Infrastructure Excavation': 94, 'New Ground Excavation': 95, 'Residential Roofing Services': 96, 'Roofing Services with Heat Application': 97, 'Waterproofing Services': 98, 'Septic System Services': 99, 'Building Cleaning Services': 100, 'Fire Safety Equipment Services': 101, 'Testing and Inspection Services': 102, 'Single Family Residential Construction': 103, 'Single Family Renovation Services': 104, 'Multi-Family Construction Services': 105, 'Apartment Renovation Services': 106, 'Restoration Services': 107, 'Mobile Home Construction Services': 108, 'Commercial Construction Services': 109, 'Commercial Renovation Services': 110, 'Swimming Pool Installation Services': 111, 'Swimming Pool Maintenance Services': 112, 'Vacant Building Management': 113, 'Vacant Land Services': 114, 'Meat Processing S ...
# {1: 'Agricultural Equipment Services', 2: 'Soil Nutrient Application Services', 3: 'Pesticide Application Services', 4: 'Ornamental Plant Nurseries', 5: 'Landscaping Services', 6: 'Gardening Services', 7: 'Tree Services - Pruning / Removal', 8: 'Veterinary Services', 9: 'Veterinary Clinics', 10: 'Pet Boarding Services', 11: 'Animal Day Care Services', 12: 'Pet Grooming Services', 13: 'Animal Training Services', 14: 'Veterinary Health Centers', 15: 'Animal Trainers', 16: 'Livestock Dealer Services', 17: 'Timber Harvesting Operations', 18: 'Fishing and Hunting Services', 19: 'Well Maintenance Services', 20: 'Field Welding Services', 21: 'Sand and Gravel Mining', 22: 'Residential Driveway Construction', 23: 'Commercial Driveway Construction', 24: 'Fencing Construction Services', 25: 'Sidewalk Construction Services', 26: 'Commercial Irrigation Systems', 27: 'Residential Drainage Systems', 28: 'Residential Snow Removal', 29: 'Commercial Snow Removal', 30: 'General Snow Removal Services', 31: 'Land Leveling Services', 32: 'Residential Drain Cleaning', 33: 'Commercial Drain Cleaning', 34: 'Street Cleaning Operations', 35: 'Conveyor System Installation', 36: 'Low-Rise Signage Installation', 37: 'High-Rise Signage Installation', 38: 'Tank Installation Services', 39: 'Residential Communication Equipment Installation', 40: 'Commercial Communication Equipment Installation', 41: 'Low-Rise Glass Installation', 42: 'High-Rise Glass Installation', 43: 'Industrial Machinery Installation', 44: 'Agricultural Machinery Installation', 45: 'Grain Handling Machinery Installation', 46: 'Dock and Pier Construction', 47: 'Road and Highway Construction', 48: 'Road Maintenance Services', 49: 'Pipeline Construction Services', 50: 'New Ground Pipeline Installation', 51: 'Excavation Services', 52: 'Residential Plumbing Services', 53: 'Commercial Plumbing Services', 54: 'Industrial Plumbing Services', 55: 'Boiler Installation Services', 56: 'Boiler Repair Services', 57: 'Steam Services', 58: 'Gas Installation Services', 59: 'Medical Gas Installation Services', 60: 'Fire Protection System Services', 61: 'HVAC Installation and Service', 62: 'HVAC Inspections', 63: 'Air Duct Cleaning Services', 64: 'Water Treatment Services', 65: 'Residential Electrical Services', 66: 'Commercial Electrical Services', 67: 'Alarm Installation Services', 68: 'Electric Line Construction', 69: 'Cable Installation Services', 70: 'Elevator Installation Services', 71: 'Low-Rise Foundation Construction', 72: 'High-Rise Foundation Construction', 73: 'Precast Concrete Installation', 74: 'Tilt-Up Concrete Services', 75: 'Masonry Construction Services', 76: 'Drywall Services', 77: 'Tile Installation Services', 78: 'Carpentry Services', 79: 'Millwork Services', 80: 'General Handyman Services', 81: 'Insulation Services', 82: 'Painting Services', 83: 'Spray Painting Services', 84: 'Flooring Installation Services', 85: 'Interior Design Services', 86: 'Home Staging Services', 87: 'Sheet Metal Services', 88: 'Welding Services', 89: 'Structural Steel Erection', 90: 'Non-Structural Steel Fabrication', 91: 'Windows and Doors Installation', 92: 'Well Drilling Services', 93: 'Directional Drilling Services', 94: 'Infrastructure Excavation', 95: 'New Ground Excavation', 96: 'Residential Roofing Services', 97: 'Roofing Services with Heat Application', 98: 'Waterproofing Services', 99: 'Septic System Services', 100: 'Building Cleaning Services', 101: 'Fire Safety Equipment Services', 102: 'Testing and Inspection Services', 103: 'Single Family Residential Construction', 104: 'Single Family Renovation Services', 105: 'Multi-Family Construction Services', 106: 'Apartment Renovation Services', 107: 'Restoration Services', 108: 'Mobile Home Construction Services', 109: 'Commercial Construction Services', 110: 'Commercial Renovation Services', 111: 'Swimming Pool Installation Services', 112: 'Swimming Pool Maintenance Services', 113: 'Vacant Building Management', 114: 'Vacant Land Services', 115: 'Meat Process ...
# Landscaping Services
# {'Agricultural Equipment Services': 1, 'Soil Nutrient Application Services': 2, 'Pesticide Application Services': 3, 'Ornamental Plant Nurseries': 4, 'Landscaping Services': 5, 'Gardening Services': 6, 'Tree Services - Pruning / Removal': 7, 'Veterinary Services': 8, 'Veterinary Clinics': 9, 'Pet Boarding Services': 10, 'Animal Day Care Services': 11, 'Pet Grooming Services': 12, 'Animal Training Services': 13, 'Veterinary Health Centers': 14, 'Animal Trainers': 15, 'Livestock Dealer Services': 16, 'Timber Harvesting Operations': 17, 'Fishing and Hunting Services': 18, 'Well Maintenance Services': 19, 'Field Welding Services': 20, 'Sand and Gravel Mining': 21, 'Residential Driveway Construction': 22, 'Commercial Driveway Construction': 23, 'Fencing Construction Services': 24, 'Sidewalk Construction Services': 25, 'Commercial Irrigation Systems': 26, 'Residential Drainage Systems': 27, 'Residential Snow Removal': 28, 'Commercial Snow Removal': 29, 'General Snow Removal Services': 30, 'Land Leveling Services': 31, 'Residential Drain Cleaning': 32, 'Commercial Drain Cleaning': 33, 'Street Cleaning Operations': 34, 'Conveyor System Installation': 35, 'Low-Rise Signage Installation': 36, 'High-Rise Signage Installation': 37, 'Tank Installation Services': 38, 'Residential Communication Equipment Installation': 39, 'Commercial Communication Equipment Installation': 40, 'Low-Rise Glass Installation': 41, 'High-Rise Glass Installation': 42, 'Industrial Machinery Installation': 43, 'Agricultural Machinery Installation': 44, 'Grain Handling Machinery Installation': 45, 'Dock and Pier Construction': 46, 'Road and Highway Construction': 47, 'Road Maintenance Services': 48, 'Pipeline Construction Services': 49, 'New Ground Pipeline Installation': 50, 'Excavation Services': 51, 'Residential Plumbing Services': 52, 'Commercial Plumbing Services': 53, 'Industrial Plumbing Services': 54, 'Boiler Installation Services': 55, 'Boiler Repair Services': 56, 'Steam Services': 57, 'Gas Installation Services': 58, 'Medical Gas Installation Services': 59, 'Fire Protection System Services': 60, 'HVAC Installation and Service': 61, 'HVAC Inspections': 62, 'Air Duct Cleaning Services': 63, 'Water Treatment Services': 64, 'Residential Electrical Services': 65, 'Commercial Electrical Services': 66, 'Alarm Installation Services': 67, 'Electric Line Construction': 68, 'Cable Installation Services': 69, 'Elevator Installation Services': 70, 'Low-Rise Foundation Construction': 71, 'High-Rise Foundation Construction': 72, 'Precast Concrete Installation': 73, 'Tilt-Up Concrete Services': 74, 'Masonry Construction Services': 75, 'Drywall Services': 76, 'Tile Installation Services': 77, 'Carpentry Services': 78, 'Millwork Services': 79, 'General Handyman Services': 80, 'Insulation Services': 81, 'Painting Services': 82, 'Spray Painting Services': 83, 'Flooring Installation Services': 84, 'Interior Design Services': 85, 'Home Staging Services': 86, 'Sheet Metal Services': 87, 'Welding Services': 88, 'Structural Steel Erection': 89, 'Non-Structural Steel Fabrication': 90, 'Windows and Doors Installation': 91, 'Well Drilling Services': 92, 'Directional Drilling Services': 93, 'Infrastructure Excavation': 94, 'New Ground Excavation': 95, 'Residential Roofing Services': 96, 'Roofing Services with Heat Application': 97, 'Waterproofing Services': 98, 'Septic System Services': 99, 'Building Cleaning Services': 100, 'Fire Safety Equipment Services': 101, 'Testing and Inspection Services': 102, 'Single Family Residential Construction': 103, 'Single Family Renovation Services': 104, 'Multi-Family Construction Services': 105, 'Apartment Renovation Services': 106, 'Restoration Services': 107, 'Mobile Home Construction Services': 108, 'Commercial Construction Services': 109, 'Commercial Renovation Services': 110, 'Swimming Pool Installation Services': 111, 'Swimming Pool Maintenance Services': 112, 'Vacant Building Management': 113, 'Vacant Land Services': 114, 'Meat Processing S ...
# {1: 'Agricultural Equipment Services', 2: 'Soil Nutrient Application Services', 3: 'Pesticide Application Services', 4: 'Ornamental Plant Nurseries', 5: 'Landscaping Services', 6: 'Gardening Services', 7: 'Tree Services - Pruning / Removal', 8: 'Veterinary Services', 9: 'Veterinary Clinics', 10: 'Pet Boarding Services', 11: 'Animal Day Care Services', 12: 'Pet Grooming Services', 13: 'Animal Training Services', 14: 'Veterinary Health Centers', 15: 'Animal Trainers', 16: 'Livestock Dealer Services', 17: 'Timber Harvesting Operations', 18: 'Fishing and Hunting Services', 19: 'Well Maintenance Services', 20: 'Field Welding Services', 21: 'Sand and Gravel Mining', 22: 'Residential Driveway Construction', 23: 'Commercial Driveway Construction', 24: 'Fencing Construction Services', 25: 'Sidewalk Construction Services', 26: 'Commercial Irrigation Systems', 27: 'Residential Drainage Systems', 28: 'Residential Snow Removal', 29: 'Commercial Snow Removal', 30: 'General Snow Removal Services', 31: 'Land Leveling Services', 32: 'Residential Drain Cleaning', 33: 'Commercial Drain Cleaning', 34: 'Street Cleaning Operations', 35: 'Conveyor System Installation', 36: 'Low-Rise Signage Installation', 37: 'High-Rise Signage Installation', 38: 'Tank Installation Services', 39: 'Residential Communication Equipment Installation', 40: 'Commercial Communication Equipment Installation', 41: 'Low-Rise Glass Installation', 42: 'High-Rise Glass Installation', 43: 'Industrial Machinery Installation', 44: 'Agricultural Machinery Installation', 45: 'Grain Handling Machinery Installation', 46: 'Dock and Pier Construction', 47: 'Road and Highway Construction', 48: 'Road Maintenance Services', 49: 'Pipeline Construction Services', 50: 'New Ground Pipeline Installation', 51: 'Excavation Services', 52: 'Residential Plumbing Services', 53: 'Commercial Plumbing Services', 54: 'Industrial Plumbing Services', 55: 'Boiler Installation Services', 56: 'Boiler Repair Services', 57: 'Steam Services', 58: 'Gas Installation Services', 59: 'Medical Gas Installation Services', 60: 'Fire Protection System Services', 61: 'HVAC Installation and Service', 62: 'HVAC Inspections', 63: 'Air Duct Cleaning Services', 64: 'Water Treatment Services', 65: 'Residential Electrical Services', 66: 'Commercial Electrical Services', 67: 'Alarm Installation Services', 68: 'Electric Line Construction', 69: 'Cable Installation Services', 70: 'Elevator Installation Services', 71: 'Low-Rise Foundation Construction', 72: 'High-Rise Foundation Construction', 73: 'Precast Concrete Installation', 74: 'Tilt-Up Concrete Services', 75: 'Masonry Construction Services', 76: 'Drywall Services', 77: 'Tile Installation Services', 78: 'Carpentry Services', 79: 'Millwork Services', 80: 'General Handyman Services', 81: 'Insulation Services', 82: 'Painting Services', 83: 'Spray Painting Services', 84: 'Flooring Installation Services', 85: 'Interior Design Services', 86: 'Home Staging Services', 87: 'Sheet Metal Services', 88: 'Welding Services', 89: 'Structural Steel Erection', 90: 'Non-Structural Steel Fabrication', 91: 'Windows and Doors Installation', 92: 'Well Drilling Services', 93: 'Directional Drilling Services', 94: 'Infrastructure Excavation', 95: 'New Ground Excavation', 96: 'Residential Roofing Services', 97: 'Roofing Services with Heat Application', 98: 'Waterproofing Services', 99: 'Septic System Services', 100: 'Building Cleaning Services', 101: 'Fire Safety Equipment Services', 102: 'Testing and Inspection Services', 103: 'Single Family Residential Construction', 104: 'Single Family Renovation Services', 105: 'Multi-Family Construction Services', 106: 'Apartment Renovation Services', 107: 'Restoration Services', 108: 'Mobile Home Construction Services', 109: 'Commercial Construction Services', 110: 'Commercial Renovation Services', 111: 'Swimming Pool Installation Services', 112: 'Swimming Pool Maintenance Services', 113: 'Vacant Building Management', 114: 'Vacant Land Services', 115: 'Meat Process ...
# Landscaping Services
# Agricultural Equipment Services
# id: 1, label Counts: 541
# Health and Safety Consulting
# id: 202, label Counts: 328
# Training Services
# id: 186, label Counts: 247
# Business Development Services
# id: 179, label Counts: 212
# Paper Production Services
# id: 149, label Counts: 180
# Food Safety Services
# id: 203, label Counts: 174
# Well Maintenance Services
# id: 19, label Counts: 166
# Furniture Manufacturing
# id: 147, label Counts: 157
# Children's Clothing Manufacturing
# id: 137, label Counts: 151
# Mobile Home Construction Services
# id: 108, label Counts: 150
# Market Research Services
# id: 184, label Counts: 137
# Water Treatment Services
# id: 64, label Counts: 134
# Wood Product Manufacturing
# id: 142, label Counts: 133
# Building Cleaning Services
# id: 100, label Counts: 132
# Animal Day Care Services
# id: 11, label Counts: 131
# Commercial Construction Services
# id: 109, label Counts: 126
# Online Marketing Services
# id: 193, label Counts: 116
# HVAC Installation and Service
# id: 61, label Counts: 111
# Project Management Services
# id: 180, label Counts: 108
# Website Development Services
# id: 195, label Counts: 106
# Real Estate Services
# id: 171, label Counts: 102
# Testing and Inspection Services
# id: 102, label Counts: 101
# Electric Line Construction
# id: 68, label Counts: 100
# Sheet Metal Services
# id: 87, label Counts: 99
# Interior Design Services
# id: 85, label Counts: 98
# Financial Services
# id: 173, label Counts: 97
# Multi-Family Construction Services
# id: 105, label Counts: 92
# Quality Assurance Services
# id: 204, label Counts: 91
# Insurance Services
# id: 172, label Counts: 89
# Industrial Machinery Installation
# id: 43, label Counts: 88
# Oil and Fat Manufacturing
# id: 131, label Counts: 83
# Non-Structural Steel Fabrication
# id: 90, label Counts: 83
# Environmental Health Services
# id: 206, label Counts: 82
# Fire Protection System Services
# id: 60, label Counts: 81
# Sports Management Services
# id: 216, label Counts: 76
# Gas Manufacturing Services
# id: 153, label Counts: 76
# Travel Services
# id: 190, label Counts: 76
# Printing Services
# id: 152, label Counts: 75
# Human Resources Services
# id: 177, label Counts: 73
# Social Media Services
# id: 197, label Counts: 73
# Boiler Repair Services
# id: 56, label Counts: 73
# Community Engagement Services
# id: 209, label Counts: 70
# Non-Profit Management
# id: 214, label Counts: 69
# Roofing Services with Heat Application
# id: 97, label Counts: 68
# Sand and Gravel Mining
# id: 21, label Counts: 67
# Food Processing Services
# id: 164, label Counts: 67
# Medical Gas Installation Services
# id: 59, label Counts: 66
# Windows and Doors Installation
# id: 91, label Counts: 66
# Data Analysis Services
# id: 183, label Counts: 66
# New Ground Excavation
# id: 95, label Counts: 64
# Event Planning Services
# id: 188, label Counts: 63
# Content Creation Services
# id: 194, label Counts: 63
# Tilt-Up Concrete Services
# id: 74, label Counts: 62
# Plastic Manufacturing
# id: 155, label Counts: 62
# Waste Management Services
# id: 167, label Counts: 62
# Fishing and Hunting Services
# id: 18, label Counts: 61
# High-Rise Glass Installation
# id: 42, label Counts: 58
# Public Relations Services
# id: 187, label Counts: 56
# Commercial Electrical Services
# id: 66, label Counts: 56
# Property Management Services
# id: 170, label Counts: 53
# Catering Services
# id: 189, label Counts: 52
# Consulting Services
# id: 175, label Counts: 52
# Air Duct Cleaning Services
# id: 63, label Counts: 52
# Coffee Processing Services
# id: 124, label Counts: 50
# Technology Consulting
# id: 181, label Counts: 50
# Legal Services
# id: 174, label Counts: 50
# Meat Processing Services
# id: 115, label Counts: 49
# Marketing Services
# id: 176, label Counts: 49
# Digital Marketing Services
# id: 191, label Counts: 48
# Road Maintenance Services
# id: 48, label Counts: 46
# Window and Door Manufacturing
# id: 143, label Counts: 46
# Management Consulting
# id: 178, label Counts: 45
# Livestock Dealer Services
# id: 16, label Counts: 45
# Chemical Manufacturing
# id: 158, label Counts: 45
# Corporate Training Services
# id: 201, label Counts: 45
# Fire Safety Equipment Services
# id: 101, label Counts: 44
# Software Development Services
# id: 182, label Counts: 43
# Commercial Irrigation Systems
# id: 26, label Counts: 42
# Pet Food Manufacturing
# id: 122, label Counts: 41
# Rubber Manufacturing
# id: 160, label Counts: 40
# Physical Therapy Services
# id: 219, label Counts: 38
# Cable Installation Services
# id: 69, label Counts: 38
# Gas Installation Services
# id: 58, label Counts: 36
# Dairy Production Services
# id: 117, label Counts: 36
# Welding Services
# id: 88, label Counts: 35
# Laboratory Services
# id: 166, label Counts: 35
# Media Production Services
# id: 162, label Counts: 35
# Advertising Services
# id: 200, label Counts: 34
# Frozen Food Processing
# id: 118, label Counts: 34
# Recycling Services
# id: 168, label Counts: 34
# Commercial Communication Equipment Installation
# id: 40, label Counts: 33
# Arts Services
# id: 215, label Counts: 33
# Restoration Services
# id: 107, label Counts: 32
# Fitness Coaching
# id: 217, label Counts: 32
# Software Manufacturing
# id: 163, label Counts: 31
# Textile Manufacturing Services
# id: 133, label Counts: 31
# Street Cleaning Operations
# id: 34, label Counts: 31
# Painting Services
# id: 82, label Counts: 30
# Ice Production Services
# id: 119, label Counts: 30
# Well Drilling Services
# id: 92, label Counts: 30
# High-Rise Foundation Construction
# id: 72, label Counts: 30
# Insulation Services
# id: 81, label Counts: 30
# Non-Alcoholic Beverage Manufacturing
# id: 130, label Counts: 27
# Swimming Pool Installation Services
# id: 111, label Counts: 27
# Tree Services - Pruning / Removal
# id: 7, label Counts: 27
# Seed Processing Services
# id: 125, label Counts: 27
# Single Family Residential Construction
# id: 103, label Counts: 27
# Flooring Installation Services
# id: 84, label Counts: 27
# Vacant Land Services
# id: 114, label Counts: 26
# Field Welding Services
# id: 20, label Counts: 25
# Compliance Services
# id: 205, label Counts: 24
# Ornamental Plant Nurseries
# id: 4, label Counts: 24
# Gardening Services
# id: 6, label Counts: 24
# Animal Feed Manufacturing
# id: 121, label Counts: 24
# E-Commerce Services
# id: 192, label Counts: 23
# Strategic Planning Services
# id: 185, label Counts: 22
# Stationery Manufacturing
# id: 150, label Counts: 22
# Soil Nutrient Application Services
# id: 2, label Counts: 22
# General Handyman Services
# id: 80, label Counts: 21
# Residential Roofing Services
# id: 96, label Counts: 21
# Soap Production Services
# id: 157, label Counts: 21
# Pharmaceutical Manufacturing
# id: 165, label Counts: 20
# Ink Production Services
# id: 154, label Counts: 20
# Grain Processing Services
# id: 123, label Counts: 19
# Tile Installation Services
# id: 77, label Counts: 18
# Bakery Production Services
# id: 126, label Counts: 18
# Carpentry Services
# id: 78, label Counts: 18
# Graphic Design Services
# id: 199, label Counts: 18
# Cosmetic Manufacturing
# id: 156, label Counts: 18
# Animal Training Services
# id: 13, label Counts: 18
# Carpet Manufacturing Services
# id: 134, label Counts: 17
# Health Promotion Services
# id: 218, label Counts: 17
# Industrial Plumbing Services
# id: 54, label Counts: 16
# Low-Rise Glass Installation
# id: 41, label Counts: 16
# Road and Highway Construction
# id: 47, label Counts: 16
# Pipeline Construction Services
# id: 49, label Counts: 16
# Timber Harvesting Operations
# id: 17, label Counts: 15
# Risk Assessment Services
# id: 207, label Counts: 15
# Apparel Manufacturing
# id: 135, label Counts: 15
# Seafood Processing Services
# id: 116, label Counts: 15
# Apartment Renovation Services
# id: 106, label Counts: 14
# Pesticide Application Services
# id: 3, label Counts: 14
# Spray Painting Services
# id: 83, label Counts: 14
# Confectionery Manufacturing
# id: 127, label Counts: 14
# Corporate Responsibility Services
# id: 211, label Counts: 14
# Infrastructure Excavation
# id: 94, label Counts: 14
# Residential Electrical Services
# id: 65, label Counts: 13
# Veterinary Health Centers
# id: 14, label Counts: 13
# Agricultural Machinery Installation
# id: 44, label Counts: 12
# General Snow Removal Services
# id: 30, label Counts: 12
# Commercial Renovation Services
# id: 110, label Counts: 12
# Bedding Manufacturing
# id: 148, label Counts: 12
# Pallet Manufacturing
# id: 146, label Counts: 12
# Tank Installation Services
# id: 38, label Counts: 11
# Branding Services
# id: 198, label Counts: 11
# Accessory Manufacturing
# id: 136, label Counts: 11
# Canvas Manufacturing
# id: 139, label Counts: 11
# Conveyor System Installation
# id: 35, label Counts: 10
# Veterinary Services
# id: 8, label Counts: 10
# Fencing Construction Services
# id: 24, label Counts: 10
# Masonry Construction Services
# id: 75, label Counts: 10
# Waterproofing Services
# id: 98, label Counts: 9
# Elevator Installation Services
# id: 70, label Counts: 9
# Volunteer Services
# id: 213, label Counts: 9
# Steam Services
# id: 57, label Counts: 9
# Rope Production Services
# id: 140, label Counts: 9
# Commercial Snow Removal
# id: 29, label Counts: 9
# Asphalt Production Services
# id: 159, label Counts: 9
# Window Treatment Manufacturing
# id: 138, label Counts: 8
# Landscaping Services
# id: 5, label Counts: 8
# Commercial Drain Cleaning
# id: 33, label Counts: 8
# Residential Drainage Systems
# id: 27, label Counts: 8
# Excavation Services
# id: 51, label Counts: 7
# Grain Handling Machinery Installation
# id: 45, label Counts: 6
# Drywall Services
# id: 76, label Counts: 6
# Fundraising Services
# id: 212, label Counts: 6
# HVAC Inspections
# id: 62, label Counts: 6
# Occupational Health Services
# id: 220, label Counts: 6
# Crisis Management Services
# id: 208, label Counts: 6
# Residential Communication Equipment Installation
# id: 39, label Counts: 6
# Trim Manufacturing
# id: 145, label Counts: 5
# Alarm Installation Services
# id: 67, label Counts: 5
# Publishing Services
# id: 151, label Counts: 5
# Dock and Pier Construction
# id: 46, label Counts: 5
# Pet Grooming Services
# id: 12, label Counts: 5
# Brewery Operations
# id: 129, label Counts: 5
# Animal Trainers
# id: 15, label Counts: 4
# Rendering Services
# id: 132, label Counts: 4
# SEO Services
# id: 196, label Counts: 4
# Residential Snow Removal
# id: 28, label Counts: 4
# Pet Boarding Services
# id: 10, label Counts: 4
# Directional Drilling Services
# id: 93, label Counts: 4
# Stakeholder Services
# id: 210, label Counts: 3
# Millwork Services
# id: 79, label Counts: 3
# Tent Manufacturing Services
# id: 141, label Counts: 3
# Canning Services
# id: 120, label Counts: 3
# Precast Concrete Installation
# id: 73, label Counts: 3
# Environmental Consulting
# id: 169, label Counts: 3
# Low-Rise Foundation Construction
# id: 71, label Counts: 3
# Cabinetry Manufacturing
# id: 144, label Counts: 2
# Single Family Renovation Services
# id: 104, label Counts: 2
# Veterinary Clinics
# id: 9, label Counts: 2
# Plastic Signage Production
# id: 161, label Counts: 2
# Land Leveling Services
# id: 31, label Counts: 2
# Septic System Services
# id: 99, label Counts: 2
# Vacant Building Management
# id: 113, label Counts: 2
# Structural Steel Erection
# id: 89, label Counts: 2
# Residential Plumbing Services
# id: 52, label Counts: 2
# Boiler Installation Services
# id: 55, label Counts: 2
# Residential Driveway Construction
# id: 22, label Counts: 2
# Commercial Driveway Construction
# id: 23, label Counts: 1
# Swimming Pool Maintenance Services
# id: 112, label Counts: 1
# Distilling Services
# id: 128, label Counts: 1
# Sidewalk Construction Services
# id: 25, label Counts: 1
# Results saved to company_insurance_classification.csv
# Agricultural Equipment Services (ID: 1) - 541 companies
# Health and Safety Consulting (ID: 202) - 328 companies
# Training Services (ID: 186) - 247 companies
# Business Development Services (ID: 179) - 212 companies
# Paper Production Services (ID: 149) - 180 companies
# Food Safety Services (ID: 203) - 174 companies
# Well Maintenance Services (ID: 19) - 166 companies
# Furniture Manufacturing (ID: 147) - 157 companies
# Children's Clothing Manufacturing (ID: 137) - 151 companies
# Mobile Home Construction Services (ID: 108) - 150 companies
# Market Research Services (ID: 184) - 137 companies
# Water Treatment Services (ID: 64) - 134 companies
# Wood Product Manufacturing (ID: 142) - 133 companies
# Building Cleaning Services (ID: 100) - 132 companies
# Animal Day Care Services (ID: 11) - 131 companies
# Commercial Construction Services (ID: 109) - 126 companies
# Online Marketing Services (ID: 193) - 116 companies
# HVAC Installation and Service (ID: 61) - 111 companies
# Project Management Services (ID: 180) - 108 companies
# Website Development Services (ID: 195) - 106 companies
# Real Estate Services (ID: 171) - 102 companies
# Testing and Inspection Services (ID: 102) - 101 companies
# Electric Line Construction (ID: 68) - 100 companies
# Sheet Metal Services (ID: 87) - 99 companies
# Interior Design Services (ID: 85) - 98 companies
# Financial Services (ID: 173) - 97 companies
# Multi-Family Construction Services (ID: 105) - 92 companies
# Quality Assurance Services (ID: 204) - 91 companies
# Insurance Services (ID: 172) - 89 companies
# Industrial Machinery Installation (ID: 43) - 88 companies
# Oil and Fat Manufacturing (ID: 131) - 83 companies
# Non-Structural Steel Fabrication (ID: 90) - 83 companies
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Step 1: Load company dataset
company_df = pd.read_csv("ml_insurance_challenge.csv")

# Step 2: Load insurance taxonomy labels with corresponding insurance types
insurance_labels_df = pd.read_excel("insurance_taxonomy.xlsx", header=None, names=["Label"])
insurance_labels = insurance_labels_df["Label"].tolist()

# Remove the first element (if it's not a valid label)
insurance_labels = insurance_labels[1:]

# Step 3: Assign numerical labels to insurance categories
label_to_id = {label: idx + 1 for idx, label in enumerate(insurance_labels)}
id_to_label = {idx + 1: label for idx, label in enumerate(insurance_labels)}

# Step 4: Preprocess text descriptions
def preprocess_text(text):
    if not isinstance(text, str) or pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    tokens = re.findall(r'\b\w+\b', text)
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return " ".join(tokens)

company_df['processed_description'] = company_df['description'].apply(preprocess_text)

# Step 5: Vectorize the company descriptions and insurance labels using TF-IDF
vectorizer = TfidfVectorizer()
combined_texts = company_df['processed_description'].tolist() + insurance_labels

# Fit the vectorizer on both company descriptions and insurance labels
tfidf_matrix = vectorizer.fit_transform(combined_texts)

# Separate the company and label TF-IDF matrices
company_tfidf = tfidf_matrix[:len(company_df)]
label_tfidf = tfidf_matrix[len(company_df):]

# Step 6: Compute cosine similarity between company descriptions and insurance labels
similarity_matrix = cosine_similarity(company_tfidf, label_tfidf)

# Step 7: Assign insurance labels based on highest similarity
def assign_labels(similarity_matrix, labels, label_to_id):
    top_indices = np.argmax(similarity_matrix, axis=1)
    
    assigned_labels = []
    for index in top_indices:
        # Assign labels as numeric values
        numeric_label = label_to_id.get(labels[index], -1)
        assigned_labels.append(numeric_label)
    
    return assigned_labels

# Assign labels to companies
company_df['insurance_label_id'] = assign_labels(similarity_matrix, insurance_labels, label_to_id)

# Map label IDs back to label names
company_df['insurance_label_name'] = company_df['insurance_label_id'].map(id_to_label)

# Save results to a CSV file
output_file = "company_insurance_classification_tfidf.csv"
company_df.to_csv(output_file, index=False)

print(f"Results saved to {output_file}")

# Count occurrences of each label ID
label_counts = company_df['insurance_label_id'].value_counts()

# Print label statistics
for label in label_counts.index:
    print(f"{id_to_label[int(label)]} (ID: {label}) - {label_counts[label]} companies")

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(label_counts.index.astype(str), label_counts.values, color='skyblue')
plt.xlabel("Insurance Label ID")
plt.ylabel("Number of Companies Assigned")
plt.title("Distribution of Companies by Insurance Label ID")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alessiacolumban/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/alessiacolumban/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/alessiacolumban/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/alessiacolumban/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Results saved to company_insurance_classification_tfidf.csv
# Agricultural Equipment Services (ID: 1) - 742 companies
# Wood Product Manufacturing (ID: 142) - 346 companies
# HVAC Installation and Service (ID: 61) - 235 companies
# Business Development Services (ID: 179) - 193 companies
# Accessory Manufacturing (ID: 136) - 193 companies
# Pet Food Manufacturing (ID: 122) - 174 companies
# Electric Line Construction (ID: 68) - 167 companies
# Mobile Home Construction Services (ID: 108) - 161 companies
# Animal Day Care Services (ID: 11) - 145 companies
# Paper Production Services (ID: 149) - 142 companies
# Technology Consulting (ID: 181) - 139 companies
# Industrial Machinery Installation (ID: 43) - 138 companies
# Event Planning Services (ID: 188) - 137 companies
# Market Research Services (ID: 184) - 124 companies
# Sheet Metal Services (ID: 87) - 123 companies
# Furniture Manufacturing (ID: 147) - 121 companies
# Online Marketing Services (ID: 193) - 120 companies
# Building Cleaning Services (ID: 100) - 116 companies
